# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_documents.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df

df.to_csv('/workspace/data/final_documents.csv', index=False)

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_text_units.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
df.to_csv('/workspace/data/final_text_units.csv', index=False)

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_nodes.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                       id  human_readable_id  \
# 0       e15b692223cf4a5cb0074163c527b308                  0
# 1       0c0cce31d0654e8b820995b6c672bf95                  1
# 2       566a523d82444ea085a0bce0231b3217                  2
# 3       8306963ed1154105b18160eecbaa5ca2                  3
# 4       944cd63ee933424f9df8f599bc4fd927                  4
# ...                                  ...                ...
# 101113  a3f530b519a849e482186a54dce18ebe              19141
# 101114  221ccc0e0ca8402ea2b8a307fd3a3fbe              19142
# 101144  037f65045aac49b5b7127e9ea0fa7517              19172
# 101145  4ebfb27ee6404a7d8f8cdffd9ecad936              19173
# 101147  6bfa443dced14addbf23f1add8a08de7              19175
#
#                                                     title  community  level  \
# 0                                                  GISHEN         25      0
# 1                      RADIO CORPORATION OF AMERICA (RCA)         25      0
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_relationships.parquet')
# Adjust the display option to show the entire content of the 'summary' column
pd.set_option('display.max_colwidth', 512)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                      id  human_readable_id  \
# 0      ecefc476cb1a43b4a688df2b4a896b26                  0
# 1      974843afd17f43838b702867b1f3aee0                  1
# 2      873cbf4c723b4cad8fefcc88b09ee323                  2
# 3      3e409783289b43329fac7620f6bd7676                  3
# 4      06b91efe084d412e96922f6a3df2e1cf                  4
# ...                                 ...                ...
# 31688  874115fe200844baa199057d6ec28bc9              31688
# 31689  b55362a20aa2445c82ee327f43be056e              31689
# 31690  eb1b8bb40e6e442dab1db8c87f1a5e53              31690
# 31691  9fe45f23f1694c6aa5a86b2064b031ca              31691
# 31692  0e8193f71c4e4c89ac35e80ed0ef1b53              31692
#
#                                            source  \
# 0                                          GISHEN
# 1                                          GISHEN
# 2                                          GISHEN
# 3                                          GISHEN
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_entities.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                      id  human_readable_id  \
# 0      e15b692223cf4a5cb0074163c527b308                  0
# 1      0c0cce31d0654e8b820995b6c672bf95                  1
# 2      566a523d82444ea085a0bce0231b3217                  2
# 3      8306963ed1154105b18160eecbaa5ca2                  3
# 4      944cd63ee933424f9df8f599bc4fd927                  4
# ...                                 ...                ...
# 20232  6ed760331a0046e78bbf8f15f4a5f736              20232
# 20233  4e29b0bb9f884478ab4ffd7a32bed996              20233
# 20234  e227ae8e6cee4df787caf90643e2b0eb              20234
# 20235  be9945a49f524ef8ac8bb67ba1d15fbf              20235
# 20236  e88e913bfe17425a9a55e3442973c362              20236
#
#                                                    title           type  \
# 0                                                 GISHEN         PERSON
# 1                     RADIO CORPORATION OF AMERICA (RCA)   ORGANIZATION
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_communities.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
#df.to_csv('/workspace/data/final_communities.csv', index=False)
# Out:
#                                         id  human_readable_id  community  \
# 0     268fb6d6-013c-4d7d-a377-8dc834e53870                 25         25
# 1     dbe057b5-b983-4258-b134-8262becbe263                 29         29
# 2     31906cf2-6035-4c55-a33e-1da91d721dae                  6          6
# 3     4a4ee7c2-c5b5-493b-aae3-6cc9bd6034cb                  4          4
# 4     f1189490-362f-416b-b2f3-d04847587f49                  8          8
# ...                                    ...                ...        ...
# 3780  e8a38498-aed7-46bd-966e-1d6162cc65de               3784       3784
# 3781  5a7cc3f2-1b80-41d5-9895-035b0abb02ed               3779       3779
# 3782  eb13bc6d-262c-4a9c-ada5-a8702db26944               3780       3780
# 3783  90e19ca7-9a73-4954-9282-7db5fa9ac756               3782       3782
# 3784  50ec630d-d979-47c6-937f-c6f04bf621e9               3783       3783
#
#       level           title  \
# 0         0    Community 25
# 1         0    Community 29
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_community_reports.parquet')
# Adjust the display option to show the entire content of the 'summary' column
pd.set_option('display.max_colwidth', 500)

# # Display the DataFrame
# print(df['summary'])
df
#df.to_csv('/workspace/data/final_community_reports.csv', index=False)
# Out:
#                                         id  human_readable_id  community  \
# 0     e8d07459-ae88-41ae-a7e2-6abb92fdb7a9               3779       3779
# 1     c14820fe-8dfc-49ed-8a9a-5623d8f4495b               3780       3780
# 2     be3cea6b-7458-4dc6-998d-c0b8544edc99               3781       3781
# 3     f7837287-bd2f-444d-bd8b-cf4b72fd688c               3782       3782
# 4     3ed6c987-5093-4be8-90d9-5b4d48950af0               3783       3783
# ...                                    ...                ...        ...
# 3781  ca637f10-4dc9-446d-9e2d-0a5c302781ea                 41         41
# 3782  2db342e7-924b-45dd-8576-82fde4ec29a7                 44         44
# 3783  862978fe-ba03-44d5-870b-44727a2db3c3                 45         45
# 3784  e8fdcaaf-7543-45bb-b937-447ecdb301ee                 55         55
# 3785  37d064f3-44fa-4668-be58-dc45dbd9ec3a                 -1         -1
#
#       level  \
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
# ...

# %%
import pandas as pd

# Load the parquet file
df = pd.read_parquet('/workspace/graphrag/output/create_final_community_reports.parquet')

# Adjust display options to see the entire content of columns
pd.set_option('display.max_colwidth', 512)  # Display the entire content of cells

df['human_readable_id'] = df['human_readable_id'].astype(str)
# Filter rows where 'human_readable_id' contains a specific substring (example: 'keyword')
# filtered_df = df[df['human_readable_id'].str.contains('1176', na=False)]

ids_to_filter = ['1224', '1225', '1227', '1201', '1203', '1207']

filtered_df = df[df['human_readable_id'].isin(ids_to_filter)]

# Display the filtered DataFrame
filtered_df
# Out:
#                                         id human_readable_id  community  \
# 1020  10d7be66-493e-4729-a008-4fda1a28cfb2              1201       1201
# 1022  f601dba6-ec64-493e-93c1-6469c18952d3              1203       1203
# 1026  9a22770f-b149-44e7-8d28-905960fca9dd              1207       1207
# 1043  5dfae9bd-f28e-41b0-adcf-9d7af457d972              1224       1224
# 1044  1961f3d0-e89e-4317-90f5-29ba1c77fd02              1225       1225
# 1046  1562f220-2ea6-43f9-85e4-1fe1fd300ac1              1227       1227
#
#       level  \
# 1020      2
# 1022      2
# 1026      2
# 1043      2
# 1044      2
# 1046      2
#
#                                                                                        title  \
# 1020                                 Covenant of Quiet Enjoyment in Blake v. City of Seattle
# 1022                                      Blake v. City of Seattle: Legal Community Dynamics
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_communities.parquet')


pd.set_option('display.max_colwidth', 512)  # Display the entire content of cells

df['human_readable_id'] = df['human_readable_id'].astype(str)
# Filter rows where 'human_readable_id' contains a specific substring (example: 'keyword')
# filtered_df = df[df['human_readable_id'].str.contains('1176', na=False)]

ids_to_filter = ['1224']

filtered_df = df[df['human_readable_id'].isin(ids_to_filter)]

# Display the filtered DataFrame
filtered_df
# Out:
#                                         id human_readable_id  community  \
# 1611  60f4f0d4-9008-4833-83ad-b419cd187637              1224       1224
#
#       level           title  \
# 1611      2  Community 1224
#
#                                                                                                                                                                                                                                                                                                                                                                                                                     entity_ids  \
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_text_units.parquet')


pd.set_option('display.max_colwidth', 1024)  # Display the entire content of cells

df['id'] = df['id'].astype(str)
# Filter rows where 'human_readable_id' contains a specific substring (example: 'keyword')
# filtered_df = df[df['human_readable_id'].str.contains('1176', na=False)]

ids_to_filter = ['00d725b3f50cd24e9f02e81e58c887f9','1324776e2bcf228fce4b7d5dddb02b77','5a187d501897aa74f6c227189665ff7d','5f600f08ad81816236999c4db4b5f445']

filtered_df = df[df['id'].isin(ids_to_filter)]

# Display the filtered DataFrame
filtered_df
# Out:
#                                    id  human_readable_id  \
# 195  00d725b3f50cd24e9f02e81e58c887f9                196
# 777  5f600f08ad81816236999c4db4b5f445                778
# 865  5a187d501897aa74f6c227189665ff7d                866
# 866  1324776e2bcf228fce4b7d5dddb02b77                867
#
# ...

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag/output/create_final_entities.parquet')
pd.set_option('display.max_colwidth', 1024)  # Display the entire content of cells

df['id'] = df['id'].astype(str)
# Filter rows where 'human_readable_id' contains a specific substring (example: 'keyword')
# filtered_df = df[df['human_readable_id'].str.contains('1176', na=False)]

ids_to_filter = ['00d725b3f50cd24e9f02e81e58c887f9','1324776e2bcf228fce4b7d5dddb02b77','5a187d501897aa74f6c227189665ff7d','5f600f08ad81816236999c4db4b5f445']

filtered_df = df[df['id'].isin(ids_to_filter)]

# Display the filtered DataFrame
filtered_df
