# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_documents.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#           id  human_readable_id  \
# 0     900794                  1
# 1    1002142                  2
# 2    1008240                  3
# 3    1017694                  4
# 4    1020659                  5
# ..       ...                ...
# 358   842483                359
# 359   859403                360
# 360   869848                361
# 361   881896                362
# 362  8848167                363
#
#                                                  title  \
# 0       Jeanette Simon, executrix, vs. Celeste Solomon
# 1    M. Maurice Kind et al., Respondents, v. The Ci...
# 2    Harry Klise et al., Respondents, v. The City o...
# 3    Floyd E. Chase et al., Appellants, v. James P....
# 4    Fred Obde et al., Respondents, v. Robert L. Sc...
# ..                                                 ...
# 358  Wolten Grocery Company, Respondent, v. Puget S...
# 359  Knickerbocker Company, Respondent, v. Peder P....
# 360  Tailored Ready Company, Appellant, v. Fourth &...
# 361     Charlotte Miller vs. Merwyn K. Darby & another
# 362  Robert H. Wilkening, Sr., et al, Respondents, ...
#
#                                                   text  \
# 0    Hennessey, C.J.\nIn this appeal, a landlord ch...
# 1    Rosellini, J.\nThe plaintiffs in these actions...
# 2    Foster, J.\nPlaintiffs, husband and wife, resp...
# 3    Foster, J.\nChase and wife, plaintiffs below, ...
# 4    Finley, J.\n— Plaintiffs, Mr. and Mrs. Fred Ob...
# ..                                                 ...
# 358  Beals, J.\n— Plaintiff corporation is the owne...
# 359  Tolman, J.\nThis is an action to recover damag...
# 360  Holcomb, J.\nThis appeal is from an order deny...
# 361  Ronan, J.\nThis is an appeal from a final decr...
# 362  [As amended by order of the Court of Appeals O...
#
#                                          text_unit_ids  \
# 0    [0837a0a8204cdcba7f112a2fe2c506dc, 8772f89eb32...
# 1    [7dd00c79ff02ac1e54e98b2fa38bf527, 50367dab772...
# 2                   [4bc2b8875bafd0cbd258ebb8a1d9dc5c]
# 3    [7b9dff3a01c593120725b97cf2014493, 93ce1165522...
# 4    [97f3a22e8ef1c90e215c2d58ff0e043e, e29ee169127...
# ..                                                 ...
# 358  [c8313338ff792f5e85b3f6f4175577ab, 10a854e8145...
# 359  [0d606cc99af33a643b33b4254d3e0f7b, 350e194a9dc...
# 360  [5f6e92c6d348e7187057ed426a5fbef1, f17d516c7ad...
# 361  [b7549a40733ce46d3dabfa4c0d587080, 2bbd52b553e...
# 362  [8de495711fbe32e8753facd74195ad6a, 7593305c6a1...
#
#                                             attributes
# 0    {'court_id': '8825', 'court_name': 'Massachuse...
# 1    {'court_id': '9029', 'court_name': 'Washington...
# 2    {'court_id': '9029', 'court_name': 'Washington...
# 3    {'court_id': '9029', 'court_name': 'Washington...
# 4    {'court_id': '9029', 'court_name': 'Washington...
# ..                                                 ...
# 358  {'court_id': '9029', 'court_name': 'Washington...
# 359  {'court_id': '9029', 'court_name': 'Washington...
# 360  {'court_id': '9029', 'court_name': 'Washington...
# 361  {'court_id': '8825', 'court_name': 'Massachuse...
# 362  {'court_id': '8985', 'court_name': 'Washington...
#
# [363 rows x 6 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_text_units.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                     id  human_readable_id  \
# 0     9ec505c49b60c51e26e541d36e6f2266                  1
# 1     7904facb09a771e31571d0b75fdea4d4                  2
# 2     4ea2c5b74acc46e9f85cabc6c56b01ff                  3
# 3     512f61c6c541042f5553cb27e14bf833                  4
# 4     9adc964ce098aad1983cc8ab44272e54                  5
# ...                                ...                ...
# 1477  21873028d65054fcdb746feacc800a8a               1478
# 1478  612db2d5f8c29b284ba13f9751608f78               1479
# 1479  6bc17899e0e468c49f6a9c997246544d               1480
# 1480  c3bbd6807922e8b974aaacc59ec68a6b               1481
# 1481  4084e4e7c674cbb560b4d088c6dd4916               1482
#
#                                                    text  n_tokens  \
# 0     Braucher, J.\nThe plaintiff Gishen brought thi...      1200
# 1      until February 29, 1968. The jury determined,...      1200
# 2      matter of the agreement as it lay in the mind...      1200
# 3     st Cir.).\nEven if the parties had been dealin...      1128
# 4      Grange Mut. Liab. Co. 316 Mass. 626, 629, and...        28
# ...                                                 ...       ...
# 1477  significant” aircraft noise by form 22W, they ...      1200
# 1478   applying the [CPA] ”; and (4) therefore, the ...      1200
# 1479   (“However, it did disclose that (i) the subje...      1200
# 1480   certification ... on the theory that the . . ...      1200
# 1481   complained of involved a single transaction, ...       747
#
#      document_ids                                         entity_ids  \
# 0         [43846]  [9b4316506638484aa6a960512ef9b05b, dc333022035...
# 1         [43846]  [9b4316506638484aa6a960512ef9b05b, ee986c38e82...
# 2         [43846]  [9b4316506638484aa6a960512ef9b05b, ee986c38e82...
# 3         [43846]  [9b4316506638484aa6a960512ef9b05b, 7c797556b71...
# 4         [43846]  [453d0a2322de497eb614a00250f04282, ba8590bfc5b...
# ...           ...                                                ...
# 1477   [12453192]  [c7c57c4892d84103bd6ae9ada46fd9c7, fe4bba1ae88...
# 1478   [12453192]  [fe4bba1ae8834f52999222134f072a4a, 095873c84b7...
# 1479   [12453192]  [539e081aef884e18ab8d137367768ce2, 2b1c70a6ceb...
# 1480   [12453192]  [d87def8de9f54440b4082bacd0f9905a, 50959cb5eaa...
# 1481   [12453192]  [9d37e3afca72409ea09f4e9b30c42b86, b3dfff94cc8...
#
#                                        relationship_ids
# 0     [8308ba83b755423e82f4915761811e5c, ea9238d47dc...
# 1     [8dbdd07d2ae44e498785957d50bd96c7, d9908df2c47...
# 2     [d9908df2c47e4784993756369b3882a8, f440e96c0da...
# 3     [d9908df2c47e4784993756369b3882a8, 2615518996e...
# 4     [791633c16bfc4ebebd18bc2b3a667f29, a38e091a55e...
# ...                                                 ...
# 1477  [544f299859c942658ed222ae2999db74, 4de11827d3b...
# 1478  [7ac21a39603d43b4bd8f0e5a75ee999b, 9c497966bcf...
# 1479  [7660b32156a84c14a1043f0755c392bf, b624b031650...
# 1480  [a8b8e07342764e999af5f5f816cae956, 42dda50a334...
# 1481  [8e9f263910b147d69286d423ac261a6c, a2d7df20617...
#
# [1482 rows x 7 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_nodes.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                      id  human_readable_id  \
# 0      9b4316506638484aa6a960512ef9b05b                  0
# 1      dc3330220355478e9fbd0f7098357bf0                  1
# 2      45db98c7f4154c619c6b783d9bb123f0                  2
# 3      ee986c38e82940fa836691e46391d558                  3
# 4      0a0bd6e7265d4dab81a0f1ddc9e1eab1                  4
# ...                                 ...                ...
# 93287  58ceb9a4dbee4988bea052ed5820d3d7              18039
# 93334  8b0eca10909d43d09e14ba9c7d6762f5              18086
# 93335  93f2bb4baa3d48928ae21e3fc29532c4              18087
# 93336  47bf83c5113f456596a01622f7a02eb4              18088
# 93337  44bdac93e06d4a4fa81915e80039292d              18089
#
#                                                    title  community  level  \
# 0                                                 GISHEN         59      0
# 1                     RADIO CORPORATION OF AMERICA (RCA)         59      0
# 2                                DURA CORPORATION (DURA)         59      0
# 3                                                SURFACE         59      0
# 4      DURA BUSINESS MACHINES OF NEW ENGLAND, INC. (D...         59      0
# ...                                                  ...        ...    ...
# 93287  COMMUNICATING THE RESULTS OF CRITERION REFEREN...       3111      4
# 93334               BREACH OF REAL ESTATE AGENT'S DUTIES       3130      4
# 93335                               VIOLATION OF THE CPA       3130      4
# 93336                       DUTY TO MAKE FURTHER INQUIRY       3130      4
# 93337                                 JUSTIFIED RELIANCE       3130      4
#
#        degree  x  y
# 0          22  0  0
# 1           3  0  0
# 2           5  0  0
# 3           4  0  0
# 4           3  0  0
# ...       ... .. ..
# 93287       1  0  0
# 93334       1  0  0
# 93335       1  0  0
# 93336       1  0  0
# 93337       1  0  0
#
# [55288 rows x 8 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_relationships.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                      id  human_readable_id  \
# 0      8308ba83b755423e82f4915761811e5c                  0
# 1      ea9238d47dc74363a39dad3e98b7ef84                  1
# 2      3995f4e72772468a991711fa09025608                  2
# 3      8dbdd07d2ae44e498785957d50bd96c7                  3
# 4      e96e77754aea4fbeb4464b2e6d6e2d9f                  4
# ...                                 ...                ...
# 28720  f2f4b1c952f94f6580c34dbf8e965af3              28720
# 28721  dcba307b6fb940658b33e26e20c4c43d              28721
# 28722  3191a4c518284e72a5bc336592ea0efe              28722
# 28723  ceba873a58f3428da28a27ea8f507cab              28723
# 28724  d987e33e22a545ddaaa95c23ab8184bd              28724
#
#                                            source  \
# 0                                          GISHEN
# 1                                          GISHEN
# 2                                          GISHEN
# 3                                          GISHEN
# 4                                          GISHEN
# ...                                           ...
# 28720                     PRESUMPTION OF RELIANCE
# 28721                                  W.D. WASH.
# 28722                                  W.D. WASH.
# 28723                        DECEPTIVENESS CLAIMS
# 28724  HUTSON V. WENATCHEE FED. SAV. & LOAN ASS’N
#
#                                                   target  \
# 0                     RADIO CORPORATION OF AMERICA (RCA)
# 1                                DURA CORPORATION (DURA)
# 2      DURA BUSINESS MACHINES OF NEW ENGLAND, INC. (D...
# 3                                             COMMISSION
# 4                                                   JURY
# ...                                                  ...
# 28720                             REBUTTABLE PRESUMPTION
# 28721                                   U.S. DIST. LEXIS
# 28722                                        COURT ORDER
# 28723                                  UNFAIRNESS CLAIMS
# 28724               SAMUELSON V. CMTY. COLL. DIST. NO. 2
#
#                                              description  weight  \
# 0      Gishen is the plaintiff seeking to recover his...     8.0
# 1      Gishen was employed by Dura Corporation and is...     9.0
# 2      Gishen was the president and seventy-five per ...     6.0
# 3      Gishen asserts that he is owed a commission by...    18.0
# 4      The jury delivered a verdict in favor of Gishe...     8.0
# ...                                                  ...     ...
# 28720          Presumption of reliance can be rebuttable     9.0
# 28721  Western District of Washington cases are inclu...     7.0
# 28722  Court orders are issued by the Western Distric...     8.0
# 28723  Deceptiveness claims and unfairness claims are...     1.0
# 28724  Hutson v. Wenatchee Fed. Sav. & Loan Ass’n and...     1.0
#
#        combined_degree                                      text_unit_ids
# 0                   25                 [9ec505c49b60c51e26e541d36e6f2266]
# 1                   27                 [9ec505c49b60c51e26e541d36e6f2266]
# 2                   25                 [9ec505c49b60c51e26e541d36e6f2266]
# 3                   40  [7904facb09a771e31571d0b75fdea4d4, 9ec505c49b6...
# 4                  306                 [9ec505c49b60c51e26e541d36e6f2266]
# ...                ...                                                ...
# 28720                3                 [c3bbd6807922e8b974aaacc59ec68a6b]
# 28721                3                 [c3bbd6807922e8b974aaacc59ec68a6b]
# 28722                3                 [c3bbd6807922e8b974aaacc59ec68a6b]
# 28723                2                 [c3bbd6807922e8b974aaacc59ec68a6b]
# 28724                3                 [4084e4e7c674cbb560b4d088c6dd4916]
#
# [28725 rows x 8 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_entities.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                      id  human_readable_id  \
# 0      9b4316506638484aa6a960512ef9b05b                  0
# 1      dc3330220355478e9fbd0f7098357bf0                  1
# 2      45db98c7f4154c619c6b783d9bb123f0                  2
# 3      ee986c38e82940fa836691e46391d558                  3
# 4      0a0bd6e7265d4dab81a0f1ddc9e1eab1                  4
# ...                                 ...                ...
# 18147  875eb018414d463ea924ed8eed0660e7              18147
# 18148  b9dee84239d344da9146c64805381195              18148
# 18149  c86de60d2b5f4185aabdd674f3538263              18149
# 18150  172f0e7bbf5946099c9261d97fc76678              18150
# 18151  5f3e1b64c2d7435195839f58db76e9ad              18151
#
#                                                    title          type  \
# 0                                                 GISHEN        PERSON
# 1                     RADIO CORPORATION OF AMERICA (RCA)  ORGANIZATION
# 2                                DURA CORPORATION (DURA)  ORGANIZATION
# 3                                                SURFACE        PERSON
# 4      DURA BUSINESS MACHINES OF NEW ENGLAND, INC. (D...  ORGANIZATION
# ...                                                  ...           ...
# 18147                                   HUDSON V. CONDON    LEGAL CASE
# 18148                           IN RE ESTATES OF HIBBARD    LEGAL CASE
# 18149                            GREEN V. AM. PHARM. CO.    LEGAL CASE
# 18150         HUTSON V. WENATCHEE FED. SAV. & LOAN ASS’N    LEGAL CASE
# 18151               SAMUELSON V. CMTY. COLL. DIST. NO. 2    LEGAL CASE
#
#                                              description  \
# 0      Gishen is the plaintiff in a legal dispute aga...
# 1      Radio Corporation of America (RCA) is the comp...
# 2      Dura Corporation (Dura) is the defendant in th...
# 3      Surface is the general manager of Dura’s busin...
# 4      Dura Business Machines of New England, Inc. (D...
# ...                                                  ...
# 18147  Hudson v. Condon is a legal case cited in Shep...
# 18148  In re Estates of Hibbard is a legal case refer...
# 18149  Green v. Am. Pharm. Co. is a legal case cited ...
# 18150  Hutson v. Wenatchee Fed. Sav. & Loan Ass’n is ...
# 18151  Samuelson v. Cmty. Coll. Dist. No. 2 is a lega...
#
#                                            text_unit_ids
# 0      [4ea2c5b74acc46e9f85cabc6c56b01ff, 512f61c6c54...
# 1                     [9ec505c49b60c51e26e541d36e6f2266]
# 2                     [9ec505c49b60c51e26e541d36e6f2266]
# 3      [0d606cc99af33a643b33b4254d3e0f7b, 4ea2c5b74ac...
# 4                     [9ec505c49b60c51e26e541d36e6f2266]
# ...                                                  ...
# 18147                 [4084e4e7c674cbb560b4d088c6dd4916]
# 18148                 [4084e4e7c674cbb560b4d088c6dd4916]
# 18149                 [4084e4e7c674cbb560b4d088c6dd4916]
# 18150                 [4084e4e7c674cbb560b4d088c6dd4916]
# 18151                 [4084e4e7c674cbb560b4d088c6dd4916]
#
# [18152 rows x 6 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_communities.parquet')
# Adjust the display option to show the entire content of the 'summary' column
#pd.set_option('display.max_colwidth', None)

# # Display the DataFrame
#print(df['text'])
df
# Out:
#                                         id  human_readable_id  community  \
# 0     fc2c7cf6-f4af-4bdf-a047-6e8ba1efae1e                 59         59
# 1     488d1524-9ae2-4e70-b582-20acb11817f2                  1          1
# 2     15e135ce-480e-4cb2-9088-05186c105cfc                 11         11
# 3     7f4b7b8a-28a8-43ba-956a-286e3b058cde                  8          8
# 4     b4cc0e24-4066-4810-8b7b-dcf0f6eabfb0                  3          3
# ...                                    ...                ...        ...
# 3127  10517cfa-8a98-458d-bfac-20dad684e623               3130       3130
# 3128  d08ea44d-d94f-4c6e-8513-b038580be0eb               3131       3131
# 3129  56b6b033-ddd8-4f85-ac34-10f2b038731f               3117       3117
# 3130  f3853586-d3ba-4b5b-b3b6-c000df3221f5               3110       3110
# 3131  a574837d-6df4-4c89-90b4-952b39db160b               3111       3111
#
#       level           title  \
# 0         0    Community 59
# 1         0     Community 1
# 2         0    Community 11
# 3         0     Community 8
# 4         0     Community 3
# ...     ...             ...
# 3127      4  Community 3130
# 3128      4  Community 3131
# 3129      4  Community 3117
# 3130      4  Community 3110
# 3131      4  Community 3111
#
#                                              entity_ids  \
# 0     [9b4316506638484aa6a960512ef9b05b, dc333022035...
# 1     [35edfd8042f940038004752eb9cd206b, c7c57c4892d...
# 2     [7c797556b7144f58bcad34732a58f82b, e322a1f0de8...
# 3     [9f8c00381f414d86b2ee6e82c7bf0bd6, 453d0a2322d...
# 4     [1ee6a8f1d24846c4a2e3a8db9627e281, bb7904a782e...
# ...                                                 ...
# 3127  [e8c2310303ff4c58b7320a01b27775de, dc7209a69c0...
# 3128  [7a423bac54b74d7480f6137c925d7eea, f6e9aa3b8eb...
# 3129  [071b37c3e2ac43459803145e637ec3ed, 82ad8cae8fb...
# 3130  [33318683ab304fc68636625fbac9fe21, ad9fb3bd2f4...
# 3131  [bab1bc1e4d5745f5bf63613b99bc6889, 58ceb9a4dbe...
#
#                                        relationship_ids  \
# 0     [8308ba83b755423e82f4915761811e5c, ea9238d47dc...
# 1     [05cd0a14d4304df0b45a440b960b956e, 01a4ec644f8...
# 2     [f30479b1192b4d229d04a30e03330b79, a5d237ac320...
# 3     [d7ca17a18fa64ae483f208d10d5601f6, af81a106abb...
# 4     [500adbe79aaa4c7198ca41d47c36eb6f, 7b58242c9e9...
# ...                                                 ...
# 3127  [702b449e8868494f8b94b1664f4e4c56, a1860234228...
# 3128  [30a5564820e841cdb3512c983b50a5e1, 865ef76a842...
# 3129  [5baf48392786414483e0d74fbc6d6343, fb36a2a0f21...
# 3130  [09f72bc8d46a40c4a76ceffd1aff51e8, fdd0f24433d...
# 3131  [a0e5b0bbf5d046af95b24fafcc716615, 932306aca6d...
#
#                                           text_unit_ids      period  size
# 0     [4ea2c5b74acc46e9f85cabc6c56b01ff,512f61c6c541...  2024-11-26   112
# 1     [0fc6da83493b6ab84973650764ad55c1,1c5fca626401...  2024-11-26  1403
# 2     [0033b2909e055e928a9bf4d5db5d2a9d,00843f097da6...  2024-11-26   885
# 3     [573dc3a8bb46eb052a53e936318963d8,64307953af27...  2024-11-26   885
# 4     [9ec505c49b60c51e26e541d36e6f2266,b64047202fee...  2024-11-26  1820
# ...                                                 ...         ...   ...
# 3127  [11746b21533422d52795d79d02da3c3a,21873028d650...  2024-11-26    11
# 3128  [11746b21533422d52795d79d02da3c3a,38e6bc65fd54...  2024-11-26     3
# 3129  [3ac4a196f0ec91b6ae2affd6b1923de4,65dfde0f0405...  2024-11-26     2
# 3130  [0e4ea904f36b29b353354abff6a9ef39,32794a3db532...  2024-11-26    10
# 3131  [68fad28ce1b786a3b37e3614f1c69c04,df04a2cb684d...  2024-11-26     2
#
# [3132 rows x 10 columns]

# %%
import pandas as pd

# Use the absolute path to the parquet file in the output directory
df = pd.read_parquet('/workspace/graphrag_lib/output/create_final_community_reports.parquet')
# Adjust the display option to show the entire content of the 'summary' column
pd.set_option('display.max_colwidth', 100)

# # Display the DataFrame
# print(df['summary'])
df
# Out:
#                                         id  human_readable_id  community  \
# 0     cd3ce5a0-e3f2-455f-8eb2-a169b2f2385f               3104       3104
# 1     a7cab4de-15b6-4fc7-acaa-4e80540ed35e               3105       3105
# 2     a2435087-47c7-4a0b-bb0e-9232608b3ad6               3106       3106
# 3     b9d34966-5710-4bde-b3c2-e80d54d91d39               3107       3107
# 4     4ab96e63-d566-490a-b287-c071b6d839c1               3109       3109
# ...                                    ...                ...        ...
# 3127  a1237162-6e30-4a96-99d1-21c5a88092ec                 59         59
# 3128  70244031-39f4-4c58-a042-3e7986cf8c5d                 66         66
# 3129  a6d3bcc7-1050-4867-b709-c2c276571107                 68         68
# 3130  a8ebfb2a-169c-4680-8a83-ba5ac6eb5d50                 72         72
# 3131  8aeca323-6cbe-478f-9217-ce5c480f8775                 -1         -1
#
#       level  \
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
# ...     ...
# 3127      0
# 3128      0
# 3129      0
# 3130      0
# 3131      0
#
#                                                                                          title  \
# 0                     Washington Hydroculture, Inc. v. Payne: Tyler Company and Front Entrance
# 1                                 Counts and Damages in Washington Hydroculture, Inc. v. Payne
# 2                       Washington Hydroculture, Inc. v. Payne: Damages and Breach of Contract
# 3                                 Washington Hydroculture, Inc. v. Payne: Mrs. Howard's Injury
# 4                       Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships
# ...                                                                                        ...
# 3127                                                          Dura and Gishen Contract Dispute
# 3128                Washington Hydroculture, Inc. v. Payne: Legal Structures and Relationships
# 3129                    Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships
# 3130  Washington Hydroculture, Inc. v. Payne: General Contractor and Performance Bond Dynamics
# 3131                    Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships
#
#                                                                                                   summary  \
# 0     The community in the case of Washington Hydroculture, Inc. v. Payne revolves around the plaintif...
# 1     The community revolves around the legal counts and the associated damages in the case of Washing...
# 2     The community revolves around the legal case of Washington Hydroculture, Inc. v. Payne, with a f...
# 3     The community revolves around the case of Washington Hydroculture, Inc. v. Payne, with a focus o...
# 4     The community in the case of Washington Hydroculture, Inc. v. Payne revolves around key entities...
# ...                                                                                                   ...
# 3127  The community revolves around the legal dispute between Dura and Gishen over commission payments...
# 3128  The community involved in the case of Washington Hydroculture, Inc. v. Payne is characterized by...
# 3129  The community involved in the case of Washington Hydroculture, Inc. v. Payne is composed of seve...
# 3130  The community in the case of Washington Hydroculture, Inc. v. Payne is centered around the roles...
# 3131  The community involved in the case of Washington Hydroculture, Inc. v. Payne includes key entiti...
#
#                                                                                              full_content  \
# 0     # Washington Hydroculture, Inc. v. Payne: Tyler Company and Front Entrance\n\nThe community in t...
# 1     # Counts and Damages in Washington Hydroculture, Inc. v. Payne\n\nThe community revolves around ...
# 2     # Washington Hydroculture, Inc. v. Payne: Damages and Breach of Contract\n\nThe community revolv...
# 3     # Washington Hydroculture, Inc. v. Payne: Mrs. Howard's Injury\n\nThe community revolves around ...
# 4     # Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships\n\nThe community in the...
# ...                                                                                                   ...
# 3127  # Dura and Gishen Contract Dispute\n\nThe community revolves around the legal dispute between Du...
# 3128  # Washington Hydroculture, Inc. v. Payne: Legal Structures and Relationships\n\nThe community in...
# 3129  # Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships\n\nThe community involv...
# 3130  # Washington Hydroculture, Inc. v. Payne: General Contractor and Performance Bond Dynamics\n\nTh...
# 3131  # Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships\n\nThe community involv...
#
#       rank  \
# 0      8.0
# 1      8.5
# 2      9.0
# 3      8.5
# 4      8.5
# ...    ...
# 3127   8.5
# 3128   9.0
# 3129   9.0
# 3130   9.0
# 3131   8.5
#
#                                                                                          rank_explanation  \
# 0     The rating is high due to the significant impact of contractual relationships and delay claims o...
# 1     The rating is high due to the significant impact of the relationships between the counts and dam...
# 2     The analysis provides significant insights into the social structures and relationships within t...
# 3     The rating is high due to the significant impact of the relationships and hierarchies on the leg...
# 4     The rating is high due to the significant impact of the relationships and statements on the lega...
# ...                                                                                                   ...
# 3127  The rating is high due to the detailed exploration of legal obligations, transparency, and judic...
# 3128  The report provides a comprehensive and insightful analysis of the social structures, relationsh...
# 3129  The rating is high due to the comprehensive analysis of the intricate relationships and hierarch...
# 3130  The report provides a comprehensive and insightful analysis of the social structures and relatio...
# 3131  The rating is high due to the detailed analysis of the social structures and relationships that ...
#
#                                                                                                  findings  \
# 0     [{'explanation': 'The plaintiff had a contract with Tyler Company for work on the elevator and f...
# 1     [{'explanation': 'Counts One and Six are the primary grounds under which the judgments were affi...
# 2     [{'explanation': 'Damages play a central role in the legal case of Washington Hydroculture, Inc....
# 3     [{'explanation': 'Mrs. Howard is the central entity in this case, as she is the individual who a...
# 4     [{'explanation': 'Jason Files is a pivotal figure in this case, having previously been tried and...
# ...                                                                                                   ...
# 3127  [{'explanation': 'Dura is a key entity in this community, involved in a contract dispute with Gi...
# 3128  [{'explanation': 'The defendant in the case was ultimately convicted of larceny, a crime involvi...
# 3129  [{'explanation': 'The insured party is central to the case, being the entity against whom claims...
# 3130  [{'explanation': 'The General Contractor is a central entity responsible for overseeing the over...
# 3131  [{'explanation': 'Gene and Grace Luxon are central figures in this community, serving as both bu...
#
#                                                                                         full_content_json  \
# 0     {\n    "title": "Washington Hydroculture, Inc. v. Payne: Tyler Company and Front Entrance",\n   ...
# 1     {\n    "title": "Counts and Damages in Washington Hydroculture, Inc. v. Payne",\n    "summary": ...
# 2     {\n    "title": "Washington Hydroculture, Inc. v. Payne: Damages and Breach of Contract",\n    "...
# 3     {\n    "title": "Washington Hydroculture, Inc. v. Payne: Mrs. Howard's Injury",\n    "summary": ...
# 4     {\n    "title": "Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships",\n    "...
# ...                                                                                                   ...
# 3127  {\n    "title": "Dura and Gishen Contract Dispute",\n    "summary": "The community revolves arou...
# 3128  {\n    "title": "Washington Hydroculture, Inc. v. Payne: Legal Structures and Relationships",\n ...
# 3129  {\n    "title": "Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships",\n    "...
# 3130  {\n    "title": "Washington Hydroculture, Inc. v. Payne: General Contractor and Performance Bond...
# 3131  {\n    "title": "Washington Hydroculture, Inc. v. Payne: Key Entities and Relationships",\n    "...
#
#           period   size
# 0     2024-11-26    2.0
# 1     2024-11-26    2.0
# 2     2024-11-26   45.0
# 3     2024-11-26    2.0
# 4     2024-11-26    2.0
# ...          ...    ...
# 3127  2024-11-26  112.0
# 3128  2024-11-26  393.0
# 3129  2024-11-26  128.0
# 3130  2024-11-26   94.0
# 3131        None    NaN
#
# [3132 rows x 13 columns]
